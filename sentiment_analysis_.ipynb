# %% [markdown]
# <a href="https://colab.research.google.com/github/akshat5002/sentiment-analyisis-/blob/main/sentiment_analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Required Libraries

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from textblob import TextBlob
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# load data set

# %%
# Load the dataset
data = pd.read_csv('/content/3) Sentiment dataset.csv')

# %% [markdown]
# Preprocess the Text Data
# This step involves tokenization, removing stopwords, and stemming/lemmatization.

# %%
# Download NLTK resources
nltk.download('stopwords')

# Initialize the stemmer
stemmer = PorterStemmer()

# Function to preprocess text
def preprocess_text(text):
    # Tokenization
    tokens = text.split()
    # Remove stopwords and stem the words
    tokens = [stemmer.stem(word) for word in tokens if word.lower() not in stopwords.words('english')]
    return ' '.join(tokens)

# Apply preprocessing to the 'Text' column
data['Processed_Text'] = data['Text'].apply(preprocess_text)

# %% [markdown]
#  Perform Sentiment Analysis
# Use TextBlob to analyze the sentiment of the processed text.

# %%
# Function to get sentiment
def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity  # Returns a value between -1 (negative) and 1 (positive)

# Apply sentiment analysis
data['Sentiment_Score'] = data['Processed_Text'].apply(get_sentiment)

# %% [markdown]
# Visualize Sentiment Distribution
# You can visualize the sentiment distribution using a histogram.

# %%
# Plotting the sentiment distribution
plt.figure(figsize=(10, 6))
plt.hist(data['Sentiment_Score'], bins=20, color='red', alpha=0.4)
plt.title('Sentiment Score Distribution')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.grid()
plt.show()

# %% [markdown]
# Create Word Clouds
# Generate word clouds to visualize the most frequent words in positive and negative sentiments

# %%
# Create a word cloud for positive sentiments
positive_text = ' '.join(data[data['Sentiment_Score'] > 0]['Processed_Text'])
wordcloud_positive = WordCloud(width=800, height=400, background_color='green').generate(positive_text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Positive Sentiments')
plt.show()

# Create a word cloud for negative sentiments
negative_text = ' '.join(data[data['Sentiment_Score'] < 0]['Processed_Text'])
wordcloud_negative = WordCloud(width=800, height=400, background_color='black').generate(negative_text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud for Negative Sentiments')
plt.show()

# %% [markdown]
# """Analyze the Results
# Sentiment Score Distribution: The histogram will show you how the sentiments are distributed across your dataset.
# Word Clouds: The word clouds will help you visualize the most common words associated with positive and negative sentiments."""
